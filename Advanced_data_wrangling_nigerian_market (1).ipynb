# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
import os

base_path = "/content/drive/My Drive/Nigerian_Market_Data"

# Check if the directory exists
if os.path.exists(base_path):
    print(f"Contents of {base_path}:")
    for item in os.listdir(base_path):
        print(item)
else:
    print(f"The directory {base_path} does not exist. Please check the path and ensure Google Drive is mounted correctly.")

# Original code (commented out for diagnosis)
prices = pd.read_csv(f"{base_path}/nigerian_market_prices.csv.csv")
transactions = pd.read_csv(f"{base_path}/nigerian_market_transactions_assignment.csv")
# Out:
# Contents of /content/drive/My Drive/Nigerian_Market_Data:
# nigerian_market_prices.csv.csv
# nigerian_market_transactions_assignment.csv

# %%
prices.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1453993226.py in <cell line: 0>()
# ----> 1 prices.head()
#
# NameError: name 'prices' is not defined

# %%
display(prices.head())
# Out:
#   market_id    market_name  state   product   price          unit        date  \
# 0    MKT001  Bodija Market    Oyo     Beans  ₦5,770            Kg  01-02-2024
# 1    MKT003  Ogbete Market  Enugu       Yam  ₦2,534        basket  07/02/2024
# 2    MKT001  Bodija Market    Oyo       Yam     NaN          50kg  22/02/2024
# 3    MKT004    Wuse Market  Abuja  Tomatoes     NaN  Paint Rubber  29-01-2024
# 4    MKT003  Ogbete Market  Enugu      Gari   -2616            kg  2024/01/31
#
#    trader_name
# 0  mama nkechi
# 1        bello
# 2  alhaji musa
# 3  mama nkechi
# 4       sadiya

# %%
transactions.head()
# Out:
#   transaction_id market_id trader_id  trader_name   product  quantity  \
# 0        TXN0001    MKT005     TR005  ALHAJI MUSA      Gari         8
# 1        TXN0002    MKT004     TR001       SADIYA     Beans        14
# 2        TXN0003    MKT002     TR006  ALHAJI MUSA  Tomatoes         8
# 3        TXN0004    MKT003     TR001       Sadiya     Beans        13
# 4        TXN0005    MKT005     TR002  Alhaji Musa      Rice         6
#
#    revenue payment_method  transaction_date
# 0    86160       Transfer  2024-02-03 13:53
# 1   492226            POS  2024-01-05 13:46
# 2   283392       Transfer  2024-01-07 16:53
# 3   248027       Transfer  2024-03-02 10:14
# 4    46302           Cash  2024-01-27 14:37

# %%
prices.info()
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   market_id    1000 non-null   object
#  1   market_name  1000 non-null   object
#  2   state        1000 non-null   object
#  3   product      1000 non-null   object
#  4   price        925 non-null    object
#  5   unit         1000 non-null   object
#  6   date         1000 non-null   object
#  7   trader_name  1000 non-null   object
# dtypes: object(8)
# memory usage: 62.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    1000 non-null   object
#  1   market_id         1000 non-null   object
#  2   trader_id         1000 non-null   object
#  3   trader_name       1000 non-null   object
#  4   product           1000 non-null   object
#  5   quantity          1000 non-null   int64
#  6   revenue           1000 non-null   int64
#  7   payment_method    1000 non-null   object
#  8   transaction_date  1000 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 70.4+ KB

# %%
prices.columns = prices.columns.str.lower().str.strip().str.replace(" ", "_")
transactions.columns = transactions.columns.str.lower().str.strip().str.replace(" ", "_")

# %%
prices = prices.drop_duplicates()
transactions = transactions.drop_duplicates()

# %%
prices.isna().sum()
# Out:
# market_id       0
# market_name     0
# state           0
# product         0
# price          75
# unit            0
# date            0
# trader_name     0
# dtype: int64

# %%
transactions.isna().sum()
# Out:
# transaction_id      0
# market_id           0
# trader_id           0
# trader_name         0
# product             0
# quantity            0
# revenue             0
# payment_method      0
# transaction_date    0
# dtype: int64

# %%
if "price" in prices.columns:
    # Clean the 'price' column: remove currency symbol and commas, then convert to numeric
    prices["price"] = prices["price"].astype(str).str.replace('₦', '', regex=False).str.replace(',', '', regex=False)
    # Convert to numeric, coercing errors to NaN for values that can't be converted
    prices["price"] = pd.to_numeric(prices["price"], errors='coerce')
    # Fill NaN values with the median of the now numeric 'price' column
    prices["price"] = prices["price"].fillna(prices["price"].median())

# %%
transactions = transactions.dropna(subset=["market_id", "product"])

# %%
cleaned_data = pd.merge(
    transactions,
    prices,
    on=["market_id", "product"],
    how="left"
)

# %%
cleaned_data.head()
# Out:
#   transaction_id market_id trader_id trader_name_x product  quantity  revenue  \
# 0        TXN0001    MKT005     TR005   ALHAJI MUSA    Gari         8    86160
# 1        TXN0001    MKT005     TR005   ALHAJI MUSA    Gari         8    86160
# 2        TXN0001    MKT005     TR005   ALHAJI MUSA    Gari         8    86160
# 3        TXN0001    MKT005     TR005   ALHAJI MUSA    Gari         8    86160
# 4        TXN0001    MKT005     TR005   ALHAJI MUSA    Gari         8    86160
#
#   payment_method  transaction_date     market_name state   price    unit  \
# 0       Transfer  2024-02-03 13:53  Ariaria Market  Abia  2976.0  basket
# 1       Transfer  2024-02-03 13:53  Ariaria Market  Abia  4916.0  Basket
# 2       Transfer  2024-02-03 13:53  Ariaria Market  Abia  4508.0    50kg
# 3       Transfer  2024-02-03 13:53  Ariaria Market  Abia  1035.0    50kg
# 4       Transfer  2024-02-03 13:53  Ariaria Market  Abia  3293.0  basket
#
#          date trader_name_y
# 0  01-03-2024         BELLO
# 1  2024/01/11         bello
# 2  10-02-2024         bello
# 3  24/03/2024        sadiya
# 4  08-01-2024        sadiya

# %%
cleaned_data.shape
# Out:
# (40185, 15)

# %%
cleaned_data.isna().sum()
# Out:
# transaction_id      0
# market_id           0
# trader_id           0
# trader_name_x       0
# product             0
# quantity            0
# revenue             0
# payment_method      0
# transaction_date    0
# market_name         0
# state               0
# price               0
# unit                0
# date                0
# trader_name_y       0
# dtype: int64

# %%
if "price" in cleaned_data.columns:
    cleaned_data["price"] = cleaned_data["price"].fillna(cleaned_data["price"].median())

# %%
output_path = f"{base_path}/cleaned_market_data.csv"

cleaned_data.to_csv(output_path, index=False)

output_path
# Out:
# '/content/drive/My Drive/Nigerian_Market_Data/cleaned_market_data.csv'

# %%
from google.colab import files

files.download(output_path)
